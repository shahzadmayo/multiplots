# %% [markdown]
# # Facetgrid implementionn

# %%
#import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading of a dataframe from seaborn
df = sns.load_dataset('tips') 
# Form a facetgrid using columns with a hue
graph = sns.FacetGrid(df, col ="sex",  hue ="day")
# map the above form facetgrid with some attributes
graph.map(plt.scatter, "total_bill", "tip", edgecolor ="w").add_legend()
# show the object
plt.show()
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
graph = sns.FacetGrid(df, row ='smoker', col ='time')
# map the above form facetgrid with some attributes
graph.map(plt.hist, 'total_bill', bins = 15, color ='orange')
# show the object
plt.show()

# %%
# RegPlot implemention
graph = sns.FacetGrid(df, col ='time', hue ='smoker')
# map the above form facetgrid with some attributes
graph.map(sns.regplot, "total_bill", "tip").add_legend()
# show the object
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\shahzad\Desktop\multipal plots\multi_plots.ipynb Cell 5' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/shahzad/Desktop/multipal%20plots/multi_plots.ipynb#ch0000004?line=2'>3</a> # map the above form facetgrid with some attributes
#       <a href='vscode-notebook-cell:/c%3A/Users/shahzad/Desktop/multipal%20plots/multi_plots.ipynb#ch0000004?line=3'>4</a> graph.map(sns.regplot, "total_bill", "tip").add_legend()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/shahzad/Desktop/multipal%20plots/multi_plots.ipynb#ch0000004?line=4'>5</a> plt.title(color='white')
#       <a href='vscode-notebook-cell:/c%3A/Users/shahzad/Desktop/multipal%20plots/multi_plots.ipynb#ch0000004?line=5'>6</a> # show the object
#       <a href='vscode-notebook-cell:/c%3A/Users/shahzad/Desktop/multipal%20plots/multi_plots.ipynb#ch0000004?line=6'>7</a> plt.show()
#
# TypeError: title() missing 1 required positional argument: 'label'

# %% [markdown]
# # seaborn pairGrid method

# %%
df = sns.load_dataset('tips')
  
# PairGrid object with hue
graph = sns.PairGrid(df, hue ='sex')
# type of graph for diagonal
graph = graph.map_diag(plt.hist)
# type of graph for non-diagonal
graph = graph.map_offdiag(plt.scatter)
# to add legends
graph = graph.add_legend()
# to show
plt.show()

# %%
# PairGrid object with hue
graph = sns.PairGrid(df)
# type of graph for non-diagonal(upper part)
graph = graph.map_upper(sns.scatterplot)
# type of graph for non-diagonal(lower part)
graph = graph.map_lower(sns.kdeplot)
# type of graph for diagonal
graph = graph.map_diag(sns.kdeplot, lw = 2)
# to show
plt.show()
